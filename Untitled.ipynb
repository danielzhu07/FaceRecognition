# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import Lambda, Flatten, Dense
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
K.set_image_data_format('channels_last')
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
import PIL
import h5py

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

model = load_model('facenet_keras.h5')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[7], line 25
#      22 get_ipython().run_line_magic('load_ext', 'autoreload')
#      23 get_ipython().run_line_magic('autoreload', '2')
# ---> 25 model = load_model('facenet_keras.h5')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\saving\saving_api.py:194, in load_model(filepath, custom_objects, compile, safe_mode)
#     187     return saving_lib.load_model(
#     188         filepath,
#     189         custom_objects=custom_objects,
#     190         compile=compile,
#     191         safe_mode=safe_mode,
#     192     )
#     193 if str(filepath).endswith((".h5", ".hdf5")):
# --> 194     return legacy_h5_format.load_model_from_hdf5(
#     195         filepath, custom_objects=custom_objects, compile=compile
#     196     )
#     197 elif str(filepath).endswith(".keras"):
#     198     raise ValueError(
#     199         f"File not found: filepath={filepath}. "
#     200         "Please ensure the file is an accessible `.keras` "
#     201         "zip file."
#     202     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\model.py:525, in Model.from_config(cls, config, custom_objects)
#     520 if is_functional_config and revivable_as_functional:
#     521     # Revive Functional model
#     522     # (but not Functional subclasses with a custom __init__)
#     523     from keras.src.models.functional import functional_from_config
# --> 525     return functional_from_config(
#     526         cls, config, custom_objects=custom_objects
#     527     )
#     529 # Either the model has a custom __init__, or the config
#     530 # does not contain all the information necessary to
#     531 # revive a Functional model. This happens when the user creates
#    (...)
#     534 # In this case, we fall back to provide all config into the
#     535 # constructor of the class.
#     536 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:477, in functional_from_config(cls, config, custom_objects)
#     475 # First, we create all layers and enqueue nodes to be processed
#     476 for layer_data in config["layers"]:
# --> 477     process_layer(layer_data)
#     479 # Then we process nodes in order of layer depth.
#     480 # Nodes that cannot yet be processed (if the inbound node
#     481 # does not yet exist) are re-enqueued, and the process
#     482 # is repeated until all nodes are processed.
#     483 while unprocessed_nodes:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:457, in functional_from_config.<locals>.process_layer(layer_data)
#     453 # Instantiate layer.
#     454 if "module" not in layer_data:
#     455     # Legacy format deserialization (no "module" key)
#     456     # used for H5 and SavedModel formats
# --> 457     layer = saving_utils.model_from_config(
#     458         layer_data, custom_objects=custom_objects
#     459     )
#     460 else:
#     461     layer = serialization_lib.deserialize_keras_object(
#     462         layer_data, custom_objects=custom_objects
#     463     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\lambda_layer.py:192, in Lambda.from_config(cls, config, custom_objects, safe_mode)
#     190     cls._raise_for_lambda_deserialization("function", safe_mode)
#     191     inner_config = fn_config["config"]
# --> 192     fn = python_utils.func_load(
#     193         inner_config["code"],
#     194         defaults=inner_config["defaults"],
#     195         closure=inner_config["closure"],
#     196     )
#     197     config["function"] = fn
#     198 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\python_utils.py:83, in func_load(code, defaults, closure, globs)
#      81 except (UnicodeEncodeError, binascii.Error):
#      82     raw_code = code.encode("raw_unicode_escape")
# ---> 83 code = marshal.loads(raw_code)
#      84 if globs is None:
#      85     globs = globals()
#
# EOFError: EOF read where object expected
